# %%
import pandas as pd
data_licences = pd.read_parquet("data/data_licences/data_licences.parquet")

# %%
data_licences["Licences annuelles"].mean()
data_medailles = pd.read_csv("data/data_medailles/data_medailles.csv")

# %%
data_medailles
