# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize, TwoSlopeNorm
import ipywidgets as widgets
from IPython.display import display, clear_output

# %%
data_complet = pd.read_parquet("data/data_complet.parquet")
gdf_dep = gpd.read_file("departements.geojson")
data_pop = pd.read_csv("data/data_population/population_dept.csv")

# %%
# On retire les départements non cartographiables et on crée une copie
data_complet = data_complet.dropna(subset=["code_dep"]).copy()

# Conversion en string
data_complet["code_dep"] = data_complet["code_dep"].astype(str)

# %%
# Fonction d'aggrégation
def aggregate_by_year(df, year):
    df_year = df[df["Année"] == year]
    return df_year.groupby("code_dep")["Licences annuelles"].sum().reset_index()

# %%
def plot_licences(annee, sport='all', title=None):
    """
    Affiche une carte de la proportion de licenciés par département pour une année et un sport donnés.
    La proportion est exprimée en pourcentage.

    Paramètres
    ----------
    annee : int
        L'année pour laquelle afficher les données.
    sport : str, optionnel, par défaut 'all'
        Filtre par sport selon le libellé du sport. Si 'all', prend tous les sports.
    title : str, optionnel
        Titre personnalisé pour la carte. Si None, un titre par défaut est généré.

    Output
    ------
    Carte matplotlib représentant le pourcentage de licenciés par département 
    (licences_annuelles / population * 100). Les départements sans données sont indiqués 
    en gris clair avec un motif hachuré.
    """

    # Filtrage des données selon le sport sélectionné
    if sport != 'all':
        df_filtered = data_complet[data_complet["sport"] == sport]
    else:
        df_filtered = data_complet.copy()

    # Agrégation des licences par département pour l'année choisie
    df_agg_lic = df_filtered[df_filtered["annee"] == annee].groupby("code_dep")["licences_annuelles"].sum().reset_index()

    # Sélection de la population de référence selon l'année
    if annee in [2016, 2017, 2018, 2019, 2020, 2021]:
        df_pop = data_pop[data_pop["annee"] == 2016].copy()
    elif annee in [2022, 2023, 2024]:
        df_pop = data_pop[data_pop["annee"] == 2022].copy()

    # Fusion avec la géométrie des départements
    gdf_plot = gdf_dep.merge(df_agg_lic, left_on="code", right_on="code_dep", how="left")
    gdf_plot = gdf_plot.merge(df_pop[["population","code_dep"]], left_on="code", right_on="code_dep", how="left")

    # Calcul du pourcentage de licenciés par rapport à la population
    gdf_plot["licences_annuelles_relatives"] = (gdf_plot["licences_annuelles"] / gdf_plot["population"]) * 100

    # Tracé
    fig, ax = plt.subplots(figsize=(10, 12))

    gdf_plot.plot(
        column="licences_annuelles_relatives",
        ax=ax,
        legend=True,
        cmap="OrRd",
        edgecolor="grey",
        linewidth=0.5,
        missing_kwds={
            "color": "lightgrey",
            "edgecolor": "grey",
            "hatch": "//",
            "label": "Données manquantes"
        }
    )

    # Titre et suppression des axes
    ax.set_title(
        title if title else f"Proportion de licenciés (%) ({'tous les sports' if sport=='all' else sport}) par département ({annee})",
        fontsize=14
    )
    ax.set_axis_off()

    # Affichage de la carte
    plt.show()

# %%
# Code interactif pour la carte

# Préparation des options du widget

# Années disponibles
annees = sorted(data_complet["annee"].dropna().unique())

# Sports disponibles
sports = sorted(data_complet["sport"].dropna().unique())
sports = ["all"] + sports

# Création des widgets Dropdown
annee_widget = widgets.Dropdown(
    options=annees,
    description="Année :",
    value=annees[0]
)

sport_widget = widgets.Dropdown(
    options=sports,
    description="Sport :",
    value="all"
)

# Widget de sortie
out = widgets.Output()


# Fonction de mise à jour
def update_map(change=None):
    """
    Met à jour la carte interactive lorsque l'utilisateur change l'année ou le sport.
    """
    with out:
        clear_output(wait=True)
        selected_annee = annee_widget.value
        selected_sport = sport_widget.value
        plot_licences(selected_annee, sport=selected_sport)


# Liaison widgets - fonction
annee_widget.observe(update_map, names='value')
sport_widget.observe(update_map, names='value')

# Affichage initial
display(annee_widget, sport_widget, out)
update_map()

# %%
def plot_evolution(annee1, annee2, sport='all', title=None):
    """
    Affiche une carte du taux de croissance des licenciés par département 
    entre deux années pour un sport donné.

    Paramètres
    ----------
    annee1 : int
        L'année de départ pour le calcul du taux de croissance.
    annee2 : int
        L'année d'arrivée pour le calcul du taux de croissance.
    sport : str, optionnel, par défaut 'all'
        Filtre par sport selon le libellé du sport. Si 'all', prend tous les sports.
    title : str, optionnel
        Titre personnalisé pour la carte. Si None, un titre par défaut est généré.

    Output
    ------
    Carte matplotlib représentant le taux de croissance ((année2 - année1) / année1) 
    des licenciés par département. Les départements sans données sont indiqués en gris clair 
    avec un motif hachuré.
    """

    # Filtrage des données selon le sport sélectionné
    if sport != 'all':
        df_filtered = data_complet[data_complet["sport"] == sport]
    else:
        df_filtered = data_complet.copy()

    # Agrégation du nombre de licenciés par département pour chaque année
    df1 = (
        df_filtered[df_filtered["annee"] == annee1]
        .groupby("code_dep")["licences_annuelles"]
        .sum()
        .reset_index()
    )

    df2 = (
        df_filtered[df_filtered["annee"] == annee2]
        .groupby("code_dep")["licences_annuelles"]
        .sum()
        .reset_index()
    )

    # Fusion des deux années pour calculer le taux de croissance
    df_merge = df1.merge(df2, on="code_dep", suffixes=(f"_{annee1}", f"_{annee2}"))

    # Calcul du taux de croissance
    df_merge["taux"] = (
        df_merge[f"licences_annuelles_{annee2}"] - df_merge[f"licences_annuelles_{annee1}"]
    ) / df_merge[f"licences_annuelles_{annee1}"]

    # Fusion avec la géométrie des départements
    gdf_plot = gdf_dep.merge(df_merge, left_on="code", right_on="code_dep", how="left")

    # Tracé
    fig, ax = plt.subplots(figsize=(10, 12))

    gdf_plot.plot(
        column="taux",
        ax=ax,
        cmap="coolwarm",
        legend=True,
        edgecolor="grey",
        linewidth=0.5,
        vmin=-0.5,
        vmax=0.5,
        missing_kwds={
            "color": "lightgrey",
            "edgecolor": "grey",
            "hatch": "//",
            "label": "Données manquantes"
        }
    )

    # Titre de la carte et suppression des axes
    ax.set_title(
        title if title else f"Taux de croissance ({'tous les sports' if sport=='all' else sport}) des licenciés ({annee1} - {annee2})",
        fontsize=16
    )

    ax.set_axis_off()

    # Affichage de la carte
    plt.show()

# %%
# Code interactif pour la carte

# Préparation des options du widget

# Années disponibles
annees = sorted(data_complet["annee"].dropna().unique())

# Sports disponibles
sports = sorted(data_complet["sport"].dropna().unique())
sports = ["all"] + sports

# Création des widgets Dropdown
annee1_widget = widgets.Dropdown(
    options=annees,
    description="Année 1 :",
    value=annees[0]
)

annee2_widget = widgets.Dropdown(
    options=annees,
    description="Année 2 :",
    value=annees[1] if len(annees) > 1 else annees[0]
)

sport_widget = widgets.Dropdown(
    options=sports,
    description="Sport :",
    value="all"
)

# Widget de sortie
out = widgets.Output()


# Fonction de mise à jour
def update_map(change=None):
    """
    Met à jour la carte interactive lorsque l'utilisateur change l'année ou le sport.
    """
    with out:
        clear_output(wait=True)
        plot_evolution(annee1_widget.value, annee2_widget.value, sport=sport_widget.value)


# Liaison widgets - fonction
annee1_widget.observe(update_map, names='value')
annee2_widget.observe(update_map, names='value')
sport_widget.observe(update_map, names='value')

# Affichage initial
display(annee1_widget, annee2_widget, sport_widget, out)
update_map()
